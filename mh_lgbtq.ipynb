# %%
import pandas as pd

# %%
df = pd.read_excel('data/ILGA_State_Sponsored_Homophobia_2019_dataset.xlsx', sheet_name='All categories')

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN        NaN        NaN        NaN
# 1            N         CN  CONTINENT    COUNTRY
# 2            1          1     AFRICA    Algeria
# 3            2          2     AFRICA     Angola
# 4            3          3     AFRICA      Benin
# ..         ...        ...        ...        ...
# 208        NaN        NaN        NaN        NaN
# 209        NaN        NaN        NaN        NaN
# 210        NaN        NaN        NaN        NaN
# 211        NaN        NaN        NaN        NaN
# 212        NaN        NaN        NaN        NaN
#
#                                CRIMINALISATION      Unnamed: 5  \
# 0    CONSENSUAL SAME-SEX           SEXUAL ACTS          GENDER
# 1                                       Legal?        Gender/s
# 2                                           NO      ANY GENDER
# 3                                          YES  DOES NOT APPLY
# 4                                          YES  DOES NOT APPLY
# ...

# %%
df.tail(15)
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 198        191         12                                            OCEANIA
# 199        192         13                                            OCEANIA
# 200        193         14                                            OCEANIA
# 201        NaN        NaN                                                NaN
# 202        YES       (1).  In Palestine, Gaza still criminalises same-sex...
# 203         NO        NaN                                                NaN
# 204        NaN       (2).  In Indonesia, several provinces criminalise co...
# 205        NaN        NaN                                                NaN
# 206        NaN        NaN                                                NaN
# 207        NaN        NaN                                                NaN
# 208        NaN        NaN                                                NaN
# ...

# %%
for colname in df.columns:
    df.rename(columns={colname : df[colname][1]}, inplace=True)

# %%
df = df.iloc[2:201].reset_index(drop=True)

# %%
df.drop(columns={'N', 'CN', 'CONTINENT'}, inplace=True)

# %%
df
# Out:
#              COUNTRY Legal?        Gender/s Years in Prison / Other  \
# 0            Algeria     NO      ANY GENDER                       2
# 1             Angola    YES  DOES NOT APPLY          DOES NOT APPLY
# 2              Benin    YES  DOES NOT APPLY          DOES NOT APPLY
# 3           Botswana     NO      ANY GENDER                       7
# 4       Burkina Faso    YES  DOES NOT APPLY          DOES NOT APPLY
# ..               ...    ...             ...                     ...
# 194            Samoa     NO       MALE ONLY                       7
# 195  Solomon Islands     NO      ANY GENDER                      14
# 196            Tonga     NO       MALE ONLY                      10
# 197           Tuvalu     NO       MALE ONLY                      14
# 198          Vanuatu    YES  DOES NOT APPLY          DOES NOT APPLY
#
#     Constitutional Broad Protections Employment Hate Crime / Aggr. Circs.  \
# 0               NO                NO         NO                        NO
# ...

# %%
df.rename(columns={'COUNTRY':'country', 'Legal?':'legal_male', 'Gender/s':'legal_female', 
                   'Years in Prison / Other':'prison_death', 'Constitutional':'cons_protect', 
                   'Broad Protections':'broad_protect', 'Employment':'employ_protect',
                   'Hate Crime / Aggr. Circs.':'crim_hate', 'Incitement to Hatred / Violence':'crim_incite',
                   'Ban on CTs':'ban_ct', 'Marriage':'marriage', 'Civil Unions':'unions', 'Joint Adoption':'j_adopt', 'Second Parent Adoption':'sec_adopt'},
                    inplace=True)

# %%
df = df[['country', 'legal_male', 'legal_female', 'prison_death', 'cons_protect',
              'broad_protect', 'employ_protect', 'crim_hate', 'crim_incite', 'ban_ct',
              'marriage', 'unions', 'j_adopt', 'sec_adopt']]

# %%
for colname in df.columns:
    print(colname)
    print(df[colname].unique())
# Out:
# country
# ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Burundi' 'Cameroon'
#  'Cape Verde ' 'Central African Republic' 'Chad' 'Comoros' 'Congo'
#  "Côte d'Ivoire" 'DRC ' 'Djibouti' 'Egypt' 'Equatorial Guinea' 'Eritrea'
#  'Eswatini' 'Ethiopia' 'Gabon' 'Gambia' 'Ghana' 'Guinea' 'Guinea-Bissau'
#  'Kenya' 'Lesotho' 'Liberia' 'Libya' 'Madagascar' 'Malawi' 'Mali'
#  'Mauritania' 'Mauritius' 'Morocco' 'Mozambique' 'Namibia' 'Niger'
#  'Nigeria' 'Rwanda' 'São Tome & Principe' 'Senegal' 'Seychelles'
#  'Sierra Leone' 'Somalia' 'South Africa ' 'South Sudan' 'Sudan' 'Tanzania'
#  'Togo' 'Tunisia' 'Uganda' 'Zambia' 'Zimbabwe' 'Antigua and Barbuda'
#  'Argentina ' 'Bahamas ' 'Barbados' 'Belize' 'Bolivia' 'Brazil'
#  'Costa Rica ' 'Chile ' 'Colombia ' 'Cuba ' 'Dominica'
#  'Dominican Republic ' 'Ecuador ' 'El Salvador ' 'Grenada' 'Guatemala '
#  'Guyana' 'Haiti ' 'Honduras ' 'Jamaica' 'Mexico ' 'Nicaragua ' 'Panama '
#  'Paraguay' 'Peru ' 'St Kitts & Nevis' 'St Lucia'
# ...

# %%
df['legal_female'].replace(to_replace='ANY GENDER', value=0, inplace=True)
df['legal_female'].replace(to_replace='MALE ONLY', value=1, inplace=True)
df['legal_female'].replace(to_replace='M ONLY', value=1, inplace=True)
df['legal_female'].replace(to_replace='DOES NOT APPLY', value=1, inplace=True)

# %%
df.replace(to_replace={2, 7, 5, 'UNDETERMINED', 3, 14, 'DEATH (NOT)', 'DEATH (REG)', 10, 'DEATH', 'FOR LIFE', 15, 20, 8}, value=1, inplace=True)
df.replace(to_replace='DOES NOT APPLY', value=0, inplace=True)

# %%
df.replace(to_replace='NO', value=0, inplace=True)
df.replace(to_replace='YES', value=1, inplace=True)
df.replace(to_replace='DE FACTO', value=0, inplace=True)
df.replace(to_replace='N', value=0, inplace=True)
df.replace(to_replace='Y', value=1, inplace=True)
df.replace(to_replace='N ', value=0, inplace=True)
df.replace(to_replace='Y ', value=1, inplace=True)

# %%
df
# Out:
#              country  legal_male  legal_female  prison_death  cons_protect  \
# 0            Algeria           0             0             1             0
# 1             Angola           1             1             0             0
# 2              Benin           1             1             0             0
# 3           Botswana           0             0             1             0
# 4       Burkina Faso           1             1             0             0
# ..               ...         ...           ...           ...           ...
# 194            Samoa           0             1             1             0
# 195  Solomon Islands           0             0             1             0
# 196            Tonga           0             1             1             0
# 197           Tuvalu           0             1             1             0
# 198          Vanuatu           1             1             0             0
#
# ...

# %%
for colname in df.columns:
    df['country'] = df['country'].str.strip()

# %%
for colname in df.columns:
    print(colname)
    print(df[colname].unique())
# Out:
# country
# ['Algeria' 'Angola' 'Benin' 'Botswana' 'Burkina Faso' 'Burundi' 'Cameroon'
#  'Cape Verde' 'Central African Republic' 'Chad' 'Comoros' 'Congo'
#  "Côte d'Ivoire" 'DRC' 'Djibouti' 'Egypt' 'Equatorial Guinea' 'Eritrea'
#  'Eswatini' 'Ethiopia' 'Gabon' 'Gambia' 'Ghana' 'Guinea' 'Guinea-Bissau'
#  'Kenya' 'Lesotho' 'Liberia' 'Libya' 'Madagascar' 'Malawi' 'Mali'
#  'Mauritania' 'Mauritius' 'Morocco' 'Mozambique' 'Namibia' 'Niger'
#  'Nigeria' 'Rwanda' 'São Tome & Principe' 'Senegal' 'Seychelles'
#  'Sierra Leone' 'Somalia' 'South Africa' 'South Sudan' 'Sudan' 'Tanzania'
#  'Togo' 'Tunisia' 'Uganda' 'Zambia' 'Zimbabwe' 'Antigua and Barbuda'
#  'Argentina' 'Bahamas' 'Barbados' 'Belize' 'Bolivia' 'Brazil' 'Costa Rica'
#  'Chile' 'Colombia' 'Cuba' 'Dominica' 'Dominican Republic' 'Ecuador'
#  'El Salvador' 'Grenada' 'Guatemala' 'Guyana' 'Haiti' 'Honduras' 'Jamaica'
#  'Mexico' 'Nicaragua' 'Panama' 'Paraguay' 'Peru' 'St Kitts & Nevis'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         199 non-null    object
#  1   legal_male      199 non-null    int64
#  2   legal_female    199 non-null    int64
#  3   prison_death    199 non-null    int64
#  4   cons_protect    199 non-null    int64
#  5   broad_protect   199 non-null    int64
#  6   employ_protect  199 non-null    int64
#  7   crim_hate       199 non-null    int64
#  8   crim_incite     199 non-null    int64
#  9   ban_ct          199 non-null    int64
#  10  marriage        199 non-null    int64
#  11  unions          199 non-null    int64
#  12  j_adopt         199 non-null    int64
#  13  sec_adopt       199 non-null    int64
# dtypes: int64(13), object(1)
# memory usage: 21.9+ KB
